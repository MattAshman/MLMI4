# %%
import os
import sys
import re
import pdb

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(os.path.join('hello', 'there'))
# Out:
# hello/there

# %%
datasets = ['boston', 'concrete', 'energy', 'kin8nm', 'naval', 'power', 'protein', 'wine_red']
results_dir = '../results'

layers = ['2', '3', '4', '5']

# %%
layers = ['2', '3', '4', '5']
mean_nlls = np.ndarray(shape=(len(datasets), len(layers)))
std_nlls = np.ndarray(shape=(len(datasets), len(layers)))
for layer in layers:
    for dataset in datasets:
        filename = dataset + '_' + layer + '_' + '100'
        path = os.path.join(results_dir, filename)
        nll_path = path + '.nll'
        rmse_path = path + '.rsme'
        time_path = path + '.time'
        
        if os.path.isfile(nll_path):
            with open(nll_path, 'r') as f:
                s = f.read()
                results = re.findall('Split\s[0-9]*:\s(.*)\n', s, re.MULTILINE)
            results = [float(result) for result in results if result != 'nan']
            mean_nlls[datasets.index(dataset), layers.index(layer)] = np.mean(results)
            std_nlls[datasets.index(dataset), layers.index(layer)] = np.std(results)

# %%
print(mean_nlls)
print(std_nlls)
# Out:
# [[-2.50172919 -2.49960135 -2.49843954 -2.50177852]
#  [-3.17555032 -3.14674014 -3.13417215 -3.13581276]
#  [-0.68167035 -0.76355    -0.72641257 -0.71844969]
#  [ 1.34235157  1.36774536  1.34590753  1.34655501]
#  [ 6.68811112  6.80966218  6.60651407  6.74691987]
#  [-2.75085287 -2.72335247 -2.72247682 -2.72304534]
#  [-2.78823197 -2.71633324 -2.69396011 -2.69354177]
#  [-0.94971816 -0.95025551 -0.95017829 -0.95122159]]
# [[0.19906187 0.18974061 0.18817958 0.1845805 ]
#  [0.06949214 0.07741877 0.07144115 0.07504127]
#  [0.10987676 0.09832481 0.09595388 0.09522263]
#  [0.02089764 0.0232969  0.01723028 0.02392997]
#  [0.41539541 0.28031112 0.97416569 0.24255909]
#  [0.03919197 0.04355459 0.03995322 0.03718159]
#  [0.01044007 0.01191885 0.01208744 0.01197033]
#  [0.05750476 0.0572139  0.05687146 0.05693198]]

# %%
datasets = ['boston', 'concrete', 'energy', 'kin8nm', 'naval', 'power', 'protein', 'wine_red']
results_dir = '../aep_results/'

layers = ['2', '3']

aep_mean_nlls = np.ndarray(shape=(len(datasets), len(layers)))
aep_std_nlls = np.ndarray(shape=(len(datasets), len(layers)))
for layer in layers:
    for dataset in datasets:
        filename = 'aep_' + dataset + '_' + layer + '_' + '100'
        path = os.path.join(results_dir, filename)
        nll_path = path + '.nll'
        rmse_path = path + '.rsme'
        time_path = path + '.time'
                
        if os.path.isfile(nll_path):
            with open(nll_path, 'r') as f:
                s = f.read()
                results = re.findall('Split\s[0-9]*:\s(.*)\n', s, re.MULTILINE)
            results = [float(result) for result in results if result != 'nan']
            aep_mean_nlls[datasets.index(dataset), layers.index(layer)] = np.mean(results)
            aep_std_nlls[datasets.index(dataset), layers.index(layer)] = np.std(results)

# %%
print(aep_mean_nlls)
print(aep_std_nlls)
# Out:
# [[-2.36195149 -2.36947302]
#  [-3.16992435 -3.14723061]
#  [-1.40926433 -1.36873208]
#  [ 0.96440807  0.97360438]
#  [ 4.99940926  5.0600738 ]
#  [-2.85955686 -2.8589487 ]
#  [-2.96904436 -2.97096199]
#  [-0.94461939 -0.95155899]]
# [[0.12254153 0.17396337]
#  [0.06284828 0.07574546]
#  [0.05975631 0.07613012]
#  [0.03116211 0.04008257]
#  [0.39265611 0.2940701 ]
#  [0.02906236 0.02807717]
#  [0.01312277 0.01226125]
#  [0.06939394 0.07301072]]

# %%
datasets = ['boston', 'concrete', 'energy', 'kin8nm']
results_dir = '../ard_tmp/'

layers = ['2', '3', '4', '5']

ard_mean_nlls = np.ndarray(shape=(len(datasets), len(layers)))
ard_std_nlls = np.ndarray(shape=(len(datasets), len(layers)))
for layer in layers:
    for dataset in datasets:
        filename = dataset + '_' + layer + '_' + '100'
        path = os.path.join(results_dir, filename)
        nll_path = path + '.nll'
        rmse_path = path + '.rsme'
        time_path = path + '.time'
                
        if os.path.isfile(nll_path):
            with open(nll_path, 'r') as f:
                s = f.read()
                results = re.findall('Split\s[0-9]*:\s(.*)\n', s, re.MULTILINE)
            results = [float(result) for result in results if result != 'nan']
            ard_mean_nlls[datasets.index(dataset), layers.index(layer)] = np.mean(results)
            ard_std_nlls[datasets.index(dataset), layers.index(layer)] = np.std(results)

# %%
print(ard_mean_nlls)
print(ard_std_nlls)
# Out:
# [[-2.45828521 -2.39330598 -2.38223366 -2.35367162]
#  [-3.08176014 -3.05857013 -3.03987317 -3.00422572]
#  [-0.65652502 -0.53395016 -0.50946826 -0.45548041]
#  [ 1.36441654  1.38788487  1.37222003  0.07301072]]
# [[0.23730855 0.18694834 0.1703039  0.1303069 ]
#  [0.07529708 0.07155722 0.07066954 0.07401935]
#  [0.12399596 0.17447987 0.1891424  0.16972839]
#  [0.02232241 0.02689157 0.01899367 0.07301072]]

# %%
datasets = ['boston', 'concrete', 'energy', 'kin8nm', 'naval', 'power', 'protein', 'wine_red']
fig, axes = plt.subplots(nrows=1, ncols=8, figsize=(16,4))
for i, ax in enumerate(axes):
    layers = [2, 3, 4, 5]
    for layer in range(len(layers)):
        label = 'DGP-' + str(layer+2)
        ard_label = 'ARD-DGP-' + str(layer+2)
        ax.scatter(layer, mean_nlls[i, layer], label=label, marker='o', s=50)
        
        if i < ard_mean_nlls.shape[1]:
            ax.scatter(len(layers)+layer, ard_mean_nlls[i, layer], label=ard_label, marker='o', s=50)
        
    ax.scatter(2*len(layers)+1, aep_mean_nlls[i, 0], label='AEP-DGP-1', marker='x', s=50)
    ax.scatter(2*len(layers)+2, aep_mean_nlls[i, 1], label='AEP-DGP-2', marker='x', s=50)
    
    ax.set_xlabel(datasets[i], fontsize=18)

        
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.tight_layout()
plt.show()
